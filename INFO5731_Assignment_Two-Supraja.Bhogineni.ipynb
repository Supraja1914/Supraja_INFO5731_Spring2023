# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon.
#
# (2) Collect the top 10000 User Reviews of a film recently in 2023 or 2022 (you can choose any film) from IMDB.
#
# (3) Collect all the reviews of the top 1000 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from [Semantic Scholar](https://www.semanticscholar.org).
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 tweets by using a hashtag (you can use any hashtag) from Twitter.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Set the URL of the page with movie reviews
url = 'https://www.imdb.com/title/tt8178634/reviews/?ref_=tt_ql_urv'

# Send a GET request to the URL and parse the HTML content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the total number of reviews
total_reviews = soup.find('div', {'class': 'header'}).text.split()[0]

# Initialize an empty list to store the reviews
reviews = []

# Find all the review containers on the page
review_containers = soup.find_all('div', {'class': 'imdb-user-review'})

# Extract the review text and add it to the list of reviews
for review in review_containers:
    reviews.append(review.text.strip())

# Open a CSV file for writing
with open('reviews.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Review'])

    # Write each review as a row in the CSV file
    for review in reviews:
        writer.writerow([review])

    # Write the total number of reviews to the CSV file
    writer.writerow(['Total Reviews:', total_reviews])

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
# !pip install pandas nltk textblob
# Out:
# Requirement already satisfied: pandas in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (1.5.0)
# Requirement already satisfied: nltk in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (3.8.1)
# Requirement already satisfied: textblob in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (0.17.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from pandas) (2022.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\supraja\appdata\roaming\python\python310\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: click in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: six>=1.5 in c:\users\supraja\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from click->nltk) (0.4.5)

# %%
import csv
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download the NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Initialize the stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Load the stop words list
stop_words = stopwords.words('english')

# Define a function to clean the text data
def clean_text(text):
    # Remove punctuation and special characters
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.translate(str.maketrans('', '', string.digits))
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove stop words
    words = [word.lower() for word in words if word.lower() not in stop_words]
    
    # Stem the words
    #words = [stemmer.stem(word) for word in words]
    
    # Lemmatize the words
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Join the cleaned words into a string
    cleaned_text = ' '.join(words)
    
    return cleaned_text

# Open the original CSV file for reading
with open('reviews.csv', mode='r', newline='', encoding='utf-8') as input_file:
    reader = csv.reader(input_file)
    
    # Open a new CSV file for writing
    with open('cleaned_reviews.csv', mode='w', newline='', encoding='utf-8') as output_file:
        writer = csv.writer(output_file)
        
        # Loop through each row in the original CSV file
        for row in reader:
            # Skip the header row
            if row[0] == 'Review':
                header_row = ['Cleaned Review', 'Review']
                writer.writerow(header_row)
                continue
            
            # Clean the text in the second column
            cleaned_text = clean_text(row[0])
            
            # Write the cleaned text and the original text to the new CSV file
            new_row = [cleaned_text, row[0]]
            writer.writerow(new_row)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here

# !pip install nltk textblob
# Out:
# Requirement already satisfied: nltk in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (3.8.1)
# Requirement already satisfied: textblob in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (0.17.1)
# Requirement already satisfied: joblib in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\supraja\anaconda3\envs\myenv\lib\site-packages (from click->nltk) (0.4.5)

# %%
import csv
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, ne_chunk
from nltk.tree import Tree

# Download the NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# Load the stop words list
stop_words = stopwords.words('english')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Define a function to clean the text data
def clean_text(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    cleaned_sentences = []
    
    # Loop through each sentence in the text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Remove stop words
        words = [word.lower() for word in words if word.lower() not in stop_words]
        
        # Lemmatize the words
        words = [lemmatizer.lemmatize(word) for word in words]
        
        # Join the cleaned words into a string
        cleaned_sentence = ' '.join(words)
        
        cleaned_sentences.append(cleaned_sentence)
    
    # Join the cleaned sentences into a string
    cleaned_text = ' '.join(cleaned_sentences)
    
    return cleaned_text

# Open the CSV file for reading
with open('cleaned_reviews.csv', mode='r', newline='', encoding='utf-8') as input_file:
    reader = csv.reader(input_file)
    
    # Loop through each row in the CSV file
    for row in reader:
        # Skip the header row
        if row[0] == 'Cleaned Review':
            continue
        
        # Clean the text in the first column
        cleaned_text = clean_text(row[0])
        
        # Print the cleaned text
        print('Cleaned Review:', cleaned_text)
        
        # Tokenize the text into words
        words = word_tokenize(cleaned_text)
        
        # Perform POS tagging
        pos_tags = pos_tag(words)
        
        # Initialize the count variables
        noun_count = 0
        verb_count = 0
        adj_count = 0
        adv_count = 0
        
        # Loop through each word and count the POS tags
        for word, pos in pos_tags:
            if pos.startswith('N'):
                noun_count += 1
            elif pos.startswith('V'):
                verb_count += 1
            elif pos.startswith('J'):
                adj_count += 1
            elif pos.startswith('R'):
                adv_count += 1
        
        # Print the POS tag counts
        print('Noun count:', noun_count)
        print('Verb count:', verb_count)
        print('Adjective count:', adj_count)
        print('Adverb count:', adv_count)
        
        # Perform constituency parsing
        #parse_tree = Tree.fromstring(nltk.parse.generate(grammar, [cleaned_text])[0])
        
        # Print the constituency parse tree
        print('Constituency parse tree:')
        #print(parse_tree.pformat())
        
        # Perform dependency parsing
        #dependency_parser = nltk.parse.DependencyGraph(tree_str=parse_tree.pformat())
        
        # Print the dependency parse tree
        print('Dependency parse tree:')
       # print(dependency_parser.tree().pprint())
        
        # Perform named entity recognition
        ne_tree = ne_chunk
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Supraja\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Cleaned Review: never seen anything quite like evanstondad august seen lot movie time made lot different style different genre around world ive seen everything mainstream movie imaginable experimental cant even remember last time came away movie thinking id never seen anything like thats felt rrrthis movie much muchness may turn almost wife nearly bailed minute mark film top ridiculous got hooked totally ride point disappointed hour behemoth endingdo like see musclebound slickedup men fighting tiger check public flogging turn musical number got evil british people extremely evil england sue filmmaker defamation sure evil british people mauled rampaging jungle animal betcha beheading yep romance course homoeroticism intense watching movie may turn gay hooboy let say anything already movie isnt worth anywaywatch rrr make sure whatever first movie watch one dont care much certainly feel like palest imitation movie ever seen seriously movie deliriously bonkers unafraid absolutely absurd almost impossible watch pretty much movie disappointed one thanks lot rrrgrade found helpful review helpful sign vote permalink
# Noun count: 63
# Verb count: 32
# Adjective count: 38
# Adverb count: 17
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: rambo meshed crouching tiger musicalsay whaaaat iquine september bet youd never think mashup heavyhanded rambo mystical stunning elegance crouching tiger would work especially mixing several musical number think would wrong movie top every way pure awesomeness even hour runtime engrossed great story thorough character development young native girl effectively purchased mean british government controlling people malli presumably india small tribe belongs talented fighter stop absolutely nothing get back british government also indian soldier equally skilled dwarf soldier youll see spectacular opening scene two skilled fighter clash come together heritage root duty one hold true army work movie blew away ive never seen special effect quite like plethora frame could used sweet poster movie produced smart editing cinematography choreography modern must see found helpful review helpful sign vote permalink
# Noun count: 46
# Verb count: 29
# Adjective count: 29
# Adverb count: 15
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: wish couldve seen theater matthewssilverhammer august officially zero reason watch gray man notsosemisubtle homoerotic netflix action epic need tightrope walk complete silliness beautiful sincerity entertainment value dripping every colorful pore insane action enveloping dialogue sprawling yet intimate storytelling elaborate dancing yep admittedly unfamiliarity tone may bit much prepared hard deny bravura moviemaking daring fun found helpful review helpful sign vote permalink
# Noun count: 27
# Verb count: 12
# Adjective count: 14
# Adverb count: 4
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: weirdly spectacular jeandemichaque september pushed play really believe would ever watch whole movie wanted take look bail itwell wrong movie freaken masterpiece combine extraordinary drama stunning stunt action great photography absolutely beautiful music given bollywood movie know going watch pretty ridiculous action scene overall cheesy direction dialogue acting wont exactly oscar worthy none made enjoy movie time passed easily ended really great timethe eye candy ram charan made movie even watch worthy particular one ridiculously handsome man say p found helpful review helpful sign vote permalink
# Noun count: 32
# Verb count: 19
# Adjective count: 22
# Adverb count: 11
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: wow owenpont june incredible film never heard film netflix brought saw clip movie decided looked pretty good watched glad dancing scene party incredible arguably scene best scene film also first scene ram charan take mob people pretty awesome watch well overall definitely one best film year combining action comedy romance dancing great storytelling found helpful review helpful sign vote permalink
# Noun count: 25
# Verb count: 12
# Adjective count: 14
# Adverb count: 7
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: best superhero movie year jeremyurquhart july try review without comparing anything directly really comparable action blockbuster disappointed recently say largescale bigbudget action movie right hollywood isnt incapable making movie deliver excitement emotion many pale comparison rrr without pointing movie particular dont know whats directly comparable hollywood take notesrrr many familiar trope beat get historical epicsaction movie u trope well thing weve seen onscreen dozen time still exciting entertaining theyre used properly rrr testament thatthe amazing action probably stand core film also really good story hero want see win villain want see defeated extra conflict two main hero much movie ultimately good v evil story thats pretty straightforward honest thanks great character strong performance end enoughtheres little way slow scene dead air another reason three hour runtime fly action good complain lacklustre action modern action movie lot really happy find rrr action well amazing stunt great setup big set piece scene level brutality make feel impact combat much feel gratuitous way making thing overthetop best way possible point feel like rule consequence good guy two main hero almost superheroes arguably make rrr best superhero film yearsexcellent stuff couple lesser performance minor character occasionally clunky english dialogue british character could criticise theyre nitpicks great action movie epic warrant three hour runtime found helpful review helpful sign vote permalink
# Noun count: 101
# Verb count: 30
# Adjective count: 56
# Adverb count: 20
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: american everything modern star war marvel darklordmark july long story short word mouth happened people including heard movie areits friendship honor want well everything star war prequels everything marvel beenthis movie men super human suspension belief need view super hero movie deliversplot men hero anti hero one duty one familyits action movie think avenger civil war batman v superman modern american movie overuse cgi make movie look cheap rrr cgi place look little cheap modern big budget film deliversi give expectation low amazing action scene filmed well acting top hero moment well donehighly recommended must see found helpful review helpful sign vote permalink
# Noun count: 55
# Verb count: 16
# Adjective count: 23
# Adverb count: 5
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: rajamouli delivers power packed action entertainer made big screen csrahulkumar march last time director rajamouli managed wow audience film baahubali conclusion took long year conceptualise next film rrr shoot bring silver screen pulling multistarrer jr ntr ram charan lead role might seem accomplishment rajamouli manages deliver even come storyrrr set revolves around life two revolutionary alluri seetharama raju waged armed campaign british komaram bheem tribal gond tribe fought atrocity heaped people historical evidence show two ever met fought together rajamouli reimagines history weave story around meetingrrr run relatively simple premise fire angry young police officer ramaraju ram charan revered feared british done every bidding year one sic anyone want capture yet one never given enough respect due colour skin water sweet simple innocent bheem jr ntr brute strength u serf purpose gond tribal come city rescue young girl called malli taken away lady scott alison doody singing doll mantelpiece beginning talerajamoulis new calling card seem building new world despite based two revolutionary history rrr story thats completely fictional delhi becomes new canvas bheem might fought nizams much one find imperative warn british taken lightly also find shelter muslim delhi ramaraju might seem like welltrained soldier follow instruction blindly also seems past one uncle samuthirakani know scott ray stevenson might believe brown rubbish deserve even bullet wasted jennifer olivia morris seems empathetic freedom movement turn cheek one use hand weaponsthe first half rrr run like clockwork emotional core malli song dance naatu naatu itll make smile friendship explored dosti even laugh whenever bheem try befriend jennifer cinematic liberty taken dont seem noticable later portion half film falter bit way ramarajus fiancé sita alia bhatt woven narrative apart ram charans transformation another look also seem forced tale smooth sailing way bheem set effortlessly despite nothing much told way ramarajus story unfolds seems strained climax leaf desired good thing however film manages surprise rajamouli also manages use certain trope set initial portion film latter portion cleverlynonetheless rajamouli manages pull something people pining commercial action drama keep thoroughly entertained length also doesnt prove hindrance thanks tight screenplay vfx certain portion couldve better jr ntr pull career best performance charming bheem especially emotional bit desperation find malli come well love ramaraju ram charan also well pouring soul transformation character go tarak charans role require chemistry alia bhatt olivia morris samuthirakani ajay devgn shriya saran others play part well olivia particular manages win heart alison ray breeze role keeravanis ost film might everyone well bgm senthils camerawork delight toorrr made big screen viewing cinematography visual aesthetic paint every frame radiating manner oodles flamboyance something one come expect rajamouli background score thud relentless urgency repetition unapologetically melodramatic quite smitten numbs u submission postinterval pace falter little pleasure dwindle toorrr perfection mean way rajamouli pull certain scene wonder couldve done better job others watch one weekend youve longing good action packed drama especially youre fan lead duo found helpful review helpful sign vote permalink
# Noun count: 225
# Verb count: 89
# Adjective count: 103
# Adverb count: 41
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: rousing rampaging revolutionary xstal december strike recent time many film coming traditional western studio lay claim spectacular yet whenever venture studio india array language innovation story rich gorged upon seldom short extensive quite often spectacular one film jaw dropping piece good old patriotic prowess rip three hour leaf desperate three read review others want know story take overwhelming entertainment spectacle grandest way set fire par anything may come across past sure replayed many time get hook surely irresistible found helpful review helpful sign vote permalink
# Noun count: 32
# Verb count: 15
# Adjective count: 26
# Adverb count: 6
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: probably brutally violent pg plus dance battle quinoa april total militaristic propaganda scale immense scope david lean bloody brutalist mel gibson certainly nowhere near subtle former well duh kid also manages rapturously stupid gruesome violence anything latter would wife also pointed zack snyder far superior visa vi man something say loud slow mo concur point dont like british people boy girl got smorgasbord f brit alright one good lady onebut experiencing minute rrr truly final peppy totally dissonant music number included run time going eat buffet going leave like hour somber powerful war movie gritty run jungle slaughter fest cornball treatise friendship time literally fiery call arm british colonial power sliver romance good measure bheem five ten minute deliriously exciting step danceoff movie exhausting crude time laughable cgi animal oh absolute blast know youre two hero first meet bridge surrounded fire youre leave dont come backi know historically accurate lol need accuracy exploitationmeter need break glass becomes superhero bent saving everyone gun gloriously crazy totally sincere oh ray stevenson performance career aamir khan star easy found helpful review helpful sign vote permalink
# Noun count: 78
# Verb count: 27
# Adjective count: 44
# Adverb count: 20
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: movie end like completing festival celebration mramanan march rated language telugu medium partner zee source nil highly recommendedmovie start two hero introduction like full meal satisfactionreally trailer shown movie much action block goosebump moment movie real double treat mass moment also doubled dual hero naattu song cherry top whole theatre go mad one interval block action sequence real jaw dropping one even though guess one cant guess scalesecond half start bit slow flashback pick peak immediately second half sentiment screen space rc rc outshines ntr lot place action block gravity defying enjoyable credit janta song cameo rajamouli movie end like completing festival celebrationexceeding expectation aspect found helpful review helpful sign vote permalink
# Noun count: 63
# Verb count: 11
# Adjective count: 23
# Adverb count: 5
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: rajamouli filmmaker hasnt lost root magadalwarmayur march warning spoiler im native telugu speaking audience first time exposed rajamouli saw eega movie also watched heard ajay devgan dubbing film day day say im fanboyrrr bleeds rajamouli every frame action dance mundain dilogue call rajamouli pitch film filmis three hour long never feel like itthe editing cinematography awesome bad thing film song good favourite filmsthe film casted perfectly ram charan played wonderful character ntr restraint yet powerful presence film alia bhatt graceful foreign actor well casted special mention olivia moris ajay devgan awesome even limited screen presence would tempted say outperormed hero filmthe best thing film though action choreography expected good surpassed expectation go visual effectsthe action set peieces meticulously planned perfectly excutedthe film leave wow touch heart one way anotherone wonderful film seen past year found helpful review helpful sign vote permalink
# Noun count: 69
# Verb count: 27
# Adjective count: 26
# Adverb count: 10
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: hilariously ridiculous stupid andrewchristianjr june action scene badass hilariously ridiculous stupid loved basically superhero movie two actor also important part made scene entertaining story bad even though dragged much middle part found helpful review helpful sign vote permalink
# Noun count: 14
# Verb count: 5
# Adjective count: 12
# Adverb count: 5
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: ravishing refreshing recommendable prashastsingh april warning spoiler magadheera eega baahubali movie mere teaser rajamouli capable filmmaker rrr feature length definition ability create cinema transcends language nativity barrier eventually delivering many try fail deliver universal entertainment rrr intense action drama making perfect visual spectacle experiencing would make better ranging grand production value resonant emotion outstanding action sequence rrr epic every sense word truly ravishing refreshing recommendablethe film might around three hour long never actually feel like long film fact time fly really quick watching rrr explosive cinematic blockbuster entertainment age spite ua rating cinematography visual effect fight dance choreography key highlight film aside terrific performance jr ntr ram charan others ajay devgn alia bhatt shine brief yet integral role one good thing song never hinder storytelling instead make experience fun fight stunt totally dominate show deliver bang buck action buff could ask forplus director rajamouli beautifully handled depiction film two hero giving balanced amount focus viewer never call one main hero also background music gold major asset proceeding editing razorsharp set look grand rrr reinstates fact rajamouli undisputed king period action drama india filmmaker lot learn would definitely recommend watching rrr suggest leave seat end otherwise might miss important part cinema exists dont need think much booking ticket found helpful review helpful sign vote permalink
# Noun count: 100
# Verb count: 42
# Adjective count: 40
# Adverb count: 19
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: storytelling setup payoff bradclayton september rrrs strength easily worth suspending little disbelief though average blockbuster accepting style acting get past violence isnt much youre treatthere much heart movie anything ive seen long nice see movie employ slow motion convey emotion rather try magnify action great camera work fantastic music movie sound tremendous rrr know setup story beginning screentime used setup payoff lateri see violence issue though rrr nearly gory many film feel brutal timesenough cant really call family filmone best film ive seen excellent found helpful review helpful sign vote permalink
# Noun count: 41
# Verb count: 15
# Adjective count: 27
# Adverb count: 5
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: award overrated film go nathandm december rrr one critically acclaimed film year widely celebrated audience critic alike one internationally successful tollywood film time question whyim familiar tollywoodbollywood movie first one ive seen way prior watching rrr familiar bollywood clichés seen numerous infamous clip youtube theyre top presentation acting theyre long include several dancemusical number figured since first tollywood movie get kind recognition state something different movie something stood really isntas watching rrr thought american film featured story action scene length would think movie would absolutely leveled critic audience bloated tonally inconsistent bad cgi effect terrible pacing underdeveloped romantic subplots onedimensional villain guess since tollywood movie notable flaw fine add charm film dont know im honestly lowkey baffled reception rrr gettingand im also baffled tollywood film look like every indian action film come past several year seriously make movie special comparison indian blockbustershere positive give film nice direction cinematography lead actor good chemistry action scene fun also completely stupid sometimes score good sometimes random clearly indian blockbuster film ill acknowledge cinema subjective people genuinely love movie im happy still firmly stand criticism movie still think easily overrated film come year lot found helpful review helpful sign vote permalink
# Noun count: 90
# Verb count: 32
# Adjective count: 41
# Adverb count: 23
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: larger life jacethefilmguy september might uncultured usually struggle watch film subtitled dubbed film completely broke precedent loved every minute character action dancing emotion everything larger life wellexecuted mesmerizingthere element movie never seen left jaw floor film three hour long every scene necessary added emotional depth story highlight film incredible chemistry relationship two lead instant rapport harmony ram bheem inspiring make later moment poignantas whole rrr overthetop big also subtle real one moment would grinning ear ear next cry next gasping excitement though element didnt fully understand appreciate breathtaking art filmmaking anxious give another watchnote watching home would recommend watching film two three part intermission helpfulnote dancing scene alltimernote ever opportunity see theater would jump second found helpful review helpful sign vote permalink
# Noun count: 53
# Verb count: 23
# Adjective count: 26
# Adverb count: 7
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: rrr ridiculous riveting rampage great time jamesfaustino june movie one greatest movie ive seen life knowing indian movie would actually execute well especially one action best part movie scene movie go untouched without action even though part never understood saying subtitle helped understood movie scene ridiculously funny stupid made realize good movie take note hollywood movie top majority movie today found helpful review helpful sign vote permalink
# Noun count: 30
# Verb count: 13
# Adjective count: 12
# Adverb count: 7
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: pride indian cinema rrr sujathakella march watched rrr u going read review review le film tag srajamouli enough watch mind blowing charantarak performance top notch think gave carrer best performance vfxmusic production design every thing back bone film review enjoy master peice threaters❤❤🙏🙏🙏 rrr pride indian cinema take bow captain ship rajamouli garu🔥🔥 ⭐ last dont encourage piracy enjoy veralevel action scene threaters found helpful review helpful sign vote permalink
# Noun count: 45
# Verb count: 9
# Adjective count: 14
# Adverb count: 1
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: fairytale warmonger justahunch december doubt touch reviewer well critic indicated falling asleep first hour questioning film technical achievement many cgi could improved thing look real action packed somewhat monotonous three plus hour film begin girl india kidnapped british governor due wish horrid wife hundred thousand die throw logic window one everything film overthetop action story character violence even music beautiful look doubt ridiculously illogical sometimes silly though sequence pretty amazing watch turn brain viewing actor put lot especially two lead performance larger life character cecille b demille would envious found helpful review helpful sign vote permalink
# Noun count: 43
# Verb count: 14
# Adjective count: 19
# Adverb count: 11
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: weak writing sparkled rajamoulis extraordinary mass element ram charan jr ntrs largerthanlife character samthebestest march rrr movie review high low im talking akira kurosawa japanese flick im talking rajamoulis rrr actually thats best brief film think rajamouli making massfriendly commercial film long time bahubali brought panindia popularity became household name brand naturally anything would bahubali meant look smaller look comparatively le bar set high filmmaker happened prabhas came bahubali saaho radhe shyam let accept fact film like bahubali conclusion cant made massive blockbuster also kind extraordinary commercial cinema present almost impossible nowadays saw bahubali called greatest commercial entertainer millennium gadar surprisingly two film one century sell crore ticket hindi belt acceptable see heroic character bahubali film set ancient period make reasonable rrr cant held reasonable enough film set th century expect humanly possible stuff doesnt matter big fictionally character make sense come onscreen persona many legendary personality period served nation till last drop blood came human restriction rrr look problematic sense talk mass cinema rrr simply phenomenalrrr fictional tale set two indian revolutionary rama raju ram charan komaram bheem jr ntr try fight mighty british empire nizam hyderabad way interestingly opposite unknown bheem little girl abducted british officer steve ray stevenson wife lady scott alison doody rama british cop try stop two powerful hero one fire one water pitted get know agenda second half story unfolds past eventsrrr present ram charan jr ntr neverseenbefore avatar rajamouli make sure crazy mass fan following get enough content big mass party cinema hall ram charan enters minute long action scene look little extraordinary ordinary mind thats mass cinema mean right hand jr ntr got crazy mass entry class entire forest sequence blow mind good happy warning tarak fan please keep expectation high bheem going exceed pair rama bheem work like firework display largescale action sequence talking supporting cast especially two hindi actor ajay devgn alia bhatt small important cameo ajay devgn speaking intense eye news sky blue man charisma matter genius filmmaker use correctly alia bhatt sita look gorgeous every single scene character play vital part narrative olivia morris sparkle screen beauty accent cute alison doody exact opposite thats villainous character samuthirakani shriya saran appear small role pa good gradesrrrs basic script good telugu action drama mind call mindless screenplay doesnt match certain level expecting second half may bore outdated melodrama may cause little irritation flaw forgiven witness bigscreen extravaganza action sequence rrr set benchmark filmmaker india rajamouli outperforms wherever done bahubali film still battlefield reference help bit rrr despite driven two character provides better visual spectacle bahubali thats small thing mind music rrr going create hysteria theatre dont feel like dancing naacho naacho id say please consult doctor normal dosti got nice tune situational song komuram bheemudo take surprise im sure hear raamam raaghavam clearly lot noise including big scream whistle going around time youll ask repeat viewing reaching homeits two year since havent big panindia event film rajamouli brings back much needed bigscreen experience u undoubtedly best director india come commercial cinema name rajamouli extraordinary vision looking ordinary thing make better filmmaker india bahubali ordinary script rajamouli made extraordinary film matter many resemblance find lion king original source material shakespeare hamlet story every indian relate thats case rrr despite flaw writing thats rajamoulis genius mind work overtime present highoctane mass hysteria sure make mass go crazy hardcore patriotism please certain section whether introduction scene two lead actor train bridge action scene preinterval rampage even mindboggling climax f ...
# Noun count: 325
# Verb count: 102
# Adjective count: 156
# Adverb count: 32
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: vfx treat poor storyline absurd scene back dialogue alphadude march warning spoiler rrr entertaining movie boring watch mean rajamouli brings usual grandeur movie spectacle however storyline super weak jr ntrs connection kidnapped girl never established movie strong motive bring empire ram motive kill flay dozen countryman fight british get stash gun also super bizzare lot sequence movie also doesnt make sense like jr ntr spending month jungle catch wild animal transport city feed month unleash british army please funny main character miraculously recovering grave bodily blow second full costume change flicker mean cmon rajamouli bahubali epic co strong story support visuals visuals mediocre story piss poor scene cringe actor done well though good chemistry required machismo especially ram charan hopefully get fundsresources director back visuals effective story found helpful review helpful sign vote permalink
# Noun count: 70
# Verb count: 21
# Adjective count: 29
# Adverb count: 12
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: switch brain watch tajimcom march warning spoiler watched scene like top illogical dont expect rajamaulis movie boring scene well story trong vfx good section scene also good overall bahubali bahubali rajamauli disappointed found helpful review helpful sign vote permalink
# Noun count: 18
# Verb count: 6
# Adjective count: 10
# Adverb count: 3
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: magnificent movie rajamouli skmenon march warning spoiler story individual respective mission nothing india independence allalluri sitarama raju komaram bheema played ram charan junior ntr done amazing performance toiled movievisual effect action stunt bgm highlighting factor focus story line disaster commercial element required make audience watch hrsbreath taking action sequence hero introduction interval climax definitely expect rajamouli filmsabu cyril production design fantastic able met expectation directoralia bhat failed impress whereas ajay devgn done cameo performance wellrrr mass movie high octane action sequencesthe cinematography especially fabulous able say u whoaaanattu nattu song awesome could see fast pace junior ntr ram charan step proper coordination experienced big screenoverall visual impact treat pvr big screen dolby atmos watched kind effort team putso rrr mass entertainer visual impact movie found helpful review helpful sign vote permalink
# Noun count: 77
# Verb count: 19
# Adjective count: 30
# Adverb count: 2
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: everyone shouting cry flying film end byranjith june rrr patriotic period film set preindependence era see two superficial character holding gun one another turning towards common enemya remarkable cast amazing crew kindle curiosity didnt obey reality result alia bhatts performance endure gravity defying logic awfully crafted cgi increasingly violent bgm fresh dose cliched dramaif mr rajamouli put equal effort story telling technical finesse may get film surpasses bahubalis record got rrr found helpful review helpful sign vote permalink
# Noun count: 39
# Verb count: 15
# Adjective count: 18
# Adverb count: 2
# Constituency parse tree:
# Dependency parse tree:
# Cleaned Review: total review
# Noun count: 1
# Verb count: 0
# Adjective count: 1
# Adverb count: 0
# Constituency parse tree:
# Dependency parse tree:

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
Constituency parsing tree, also known as phrase structure tree, is a tree representation of the syntactic structure of a sentence. 
It breaks down a sentence into its constituent parts, such as noun phrases, verb phrases, prepositional phrases, and clauses. 
The tree structure consists of nodes and branches. Each node represents a constituent, and the branches represent the relationship between the constituents. 
For instance, the tree can show how words form a noun phrase or how a noun phrase and a verb form a clause. 
Constituency parsing tree can be used for tasks such as natural language understanding, machine translation, and text-to-speech conversion.


Dependency parsing tree, on the other hand, represents the grammatical and semantic relationships between the words in a sentence. 
It focuses on identifying the main word or headword of a sentence and its dependent words, which modify or give more information about the headword.
Dependency parsing tree also uses nodes and branches, where each node represents a word, and the branches indicate the relationship between the words. 
In this tree, the headword of a sentence is the root node, and its dependent words are connected to it via directed edges. 
For example, a preposition word like "in" will be connected to the headword it modifies, such as a noun word like "house," through a directed edge. 
Dependency parsing tree can be used for various natural language processing tasks, such as sentiment analysis, question-answering, and information extraction.
